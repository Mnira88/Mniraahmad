# %%
import numpy as np
import pandas as pd
import gensim
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec
import nltk
from nltk import sent_tokenize
import spacy
import string
import pickle
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import mysql.connector
import datetime
import time
from keras.models import load_model
import tensorflow as tf
from keras.preprocessing.sequence import pad_sequences
# Out:
# WARNING:tensorflow:From C:\Users\mnira\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = load_model('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\mnira\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Load the vectorizer
tokenizerN = 'tokenizer.pkl'
tokenizer = pickle.load(open(tokenizerN, 'rb'))
# Load the vectorizer
encoderN = 'encoder.pkl'
encoder = pickle.load(open(encoderN, 'rb'))
# Out:
# C:\Users\mnira\anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.2.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
POSITIVE = "POSITIVE"
NEGATIVE = "NEGATIVE"
NEUTRAL = "NEUTRAL"
SENTIMENT_THRESHOLDS = (0.4, 0.7)

# %%
def decode_sentiment(score, include_neutral=True):
    if include_neutral:        
        label = NEUTRAL
        if score <= SENTIMENT_THRESHOLDS[0]:
            label = NEGATIVE
        elif score >= SENTIMENT_THRESHOLDS[1]:
            label = POSITIVE

        return label
    else:
        return NEGATIVE if score < 0.5 else POSITIVE

# %%
def predict(text, include_neutral=True):
    start_at = time.time()
    # Tokenize text
    x_test = pad_sequences(tokenizer.texts_to_sequences([text]), maxlen=300)
    # Predict
    score = model.predict([x_test])[0]
    # Decode sentiment
    label = decode_sentiment(score, include_neutral=include_neutral)

    return {"label": label, "score": float(score),
       "elapsed_time": time.time()-start_at}

# %%
# Main loop
while True:
    delay = 2
    now = datetime.datetime.now()
    date_time = now.strftime("%D/%M/%Y %H:%M:%S")
    print(date_time)
    time.sleep(2)
    try:
        # Connect to the database
        mydb = mysql.connector.connect(
            host="localhost",
            port="3306",
            user="root",
            password="",
            database="emotions"
        )
        MyCursor1 = mydb.cursor()
        
        # Fetch records with status=0
        Sql_Query1 = "SELECT `id`, `content`, `result` FROM `posts` WHERE `status` = 0 ;"
        MyCursor1.execute(Sql_Query1)
        record1 = MyCursor1.fetchall()
        mydb.commit()
        MyCursor1.close()
        print("MyCursor1")
        
        if record1:
            for row in record1:
                rowID = row[0]
                rowID1 = str(rowID)
                print(rowID1)
                rowQuestion1 = row[1]
                
                if rowQuestion1:
                    msg_bullying = rowQuestion1.lower()
                    
                    # Apply vectorizer and predict
                    res_bullying = predict(msg_bullying)
                    result = res_bullying["label"]
                    print('res_bullying',result)                    
                    print("XXXXXXXXXXX")
                    
                    if res_bullying is not None:
                        # Update record with the predicted result and set status=1
                        MyCursor2 = mydb.cursor()
                        Sql_Query2 = f"UPDATE `posts` SET `status` = 1, `result`='{result}' WHERE `id`= {rowID1};"
                        MyCursor2.execute(Sql_Query2)
                        mydb.commit()
                        MyCursor2.close()
                        print("MyCursor2")
                    else:
                        print("No result")
                else:
                    print("Invalid input: rowQuestion1 is None")
        else:
            print("No records found.")
        
        mydb.close()
        print("End step")
    except Exception as e:
        print(e)
# Out:
# 05/06/24/19/2024 18:19:03
# MyCursor1
# 3
# 1/1 [==============================] - 1s 985ms/step
# res_bullying POSITIVE
# XXXXXXXXXXX
# MyCursor2
# End step
# 05/06/24/19/2024 18:19:07
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:09
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:11
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:13
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:15
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:17
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:19
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:21
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:23
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:25
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:27
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:29
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:31
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:33
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:35
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:37
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:39
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:41
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:43
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:45
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:47
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:49
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:51
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:53
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:55
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:57
# MyCursor1
# No records found.
# End step
# 05/06/24/19/2024 18:19:59
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:01
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:03
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:05
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:07
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:09
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:11
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:13
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:15
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:17
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:19
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:21
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:23
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:25
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:27
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:29
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:31
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:33
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:35
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:37
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:39
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:41
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:43
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:45
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:47
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:49
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:51
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:53
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:55
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:57
# MyCursor1
# No records found.
# End step
# 05/06/24/20/2024 18:20:59
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:01
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:03
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:05
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:07
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:09
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:11
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:13
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:15
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:17
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:19
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:21
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:23
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:25
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:27
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:29
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:31
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:33
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:35
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21:37
# MyCursor1
# No records found.
# End step
# 05/06/24/21/2024 18:21